# %%
import requests
import geopandas as gpd

bbox = [-105.3, 37.0, -104.5, 37.6]  # Example BBOX
response = requests.post("http://localhost:5001/api/fetch_trails", json={"bbox": bbox})

if response.status_code == 200:
    fetched_trails = gpd.read_file(response.text)
    print(fetched_trails.head())
else:
    print("Error:", response.text)
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[1], line 8
#       5 response = requests.post("http://localhost:5001/api/fetch_trails", json={"bbox": bbox})
#       7 if response.status_code == 200:
# ----> 8     fetched_trails = gpd.read_file(response.text)
#       9     print(fetched_trails.head())
#      10 else:
#
# File /opt/conda/envs/offroad-trip/lib/python3.11/site-packages/geopandas/io/file.py:294, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     291             from_bytes = True
#     293 if engine == "pyogrio":
# --> 294     return _read_file_pyogrio(
#     295         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     296     )
#     298 elif engine == "fiona":
#     299     if pd.api.types.is_file_like(filename):
#
# File /opt/conda/envs/offroad-trip/lib/python3.11/site-packages/geopandas/io/file.py:547, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     538     warnings.warn(
#     539         "The 'include_fields' and 'ignore_fields' keywords are deprecated, and "
#     540         "will be removed in a future release. You can use the 'columns' keyword "
#    (...)
#     543         stacklevel=3,
#     544     )
#     545     kwargs["columns"] = kwargs.pop("include_fields")
# --> 547 return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#
# File /opt/conda/envs/offroad-trip/lib/python3.11/site-packages/pyogrio/geopandas.py:265, in read_dataframe(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, fid_as_index, use_arrow, on_invalid, arrow_to_pandas_kwargs, **kwargs)
#     260 if not use_arrow:
#     261     # For arrow, datetimes are read as is.
#     262     # For numpy IO, datetimes are read as string values to preserve timezone info
#     263     # as numpy does not directly support timezones.
#     264     kwargs["datetime_as_string"] = True
# --> 265 result = read_func(
#     266     path_or_buffer,
#     267     layer=layer,
#     268     encoding=encoding,
#     269     columns=columns,
#     270     read_geometry=read_geometry,
#     271     force_2d=gdal_force_2d,
#     272     skip_features=skip_features,
#     273     max_features=max_features,
#     274     where=where,
#     275     bbox=bbox,
#     276     mask=mask,
#     277     fids=fids,
#     278     sql=sql,
#     279     sql_dialect=sql_dialect,
#     280     return_fids=fid_as_index,
#     281     **kwargs,
#     282 )
#     284 if use_arrow:
#     285     meta, table = result
#
# File /opt/conda/envs/offroad-trip/lib/python3.11/site-packages/pyogrio/raw.py:198, in read(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, return_fids, datetime_as_string, **kwargs)
#      59 """Read OGR data source into numpy arrays.
#      60
#      61 IMPORTANT: non-linear geometry types (e.g., MultiSurface) are converted
#    (...)
#     194
#     195 """
#     196 dataset_kwargs = _preprocess_options_key_value(kwargs) if kwargs else {}
# --> 198 return ogr_read(
#     199     get_vsi_path_or_buffer(path_or_buffer),
#     200     layer=layer,
#     201     encoding=encoding,
#     202     columns=columns,
#     203     read_geometry=read_geometry,
#     204     force_2d=force_2d,
#     205     skip_features=skip_features,
#     206     max_features=max_features or 0,
#     207     where=where,
#     208     bbox=bbox,
#     209     mask=_mask_to_wkb(mask),
#     210     fids=fids,
#     211     sql=sql,
#     212     sql_dialect=sql_dialect,
#     213     return_fids=return_fids,
#     214     dataset_kwargs=dataset_kwargs,
#     215     datetime_as_string=datetime_as_string,
#     216 )
#
# File pyogrio/_io.pyx:1240, in pyogrio._io.ogr_read()
#
# File pyogrio/_io.pyx:220, in pyogrio._io.ogr_open()
#
# DataSourceError: {  "redirect": "/selections"}: No such file or directory

# %%
pd.set_option('display.max_columns', None)  # Show all columns

# %%
DATA_RAW_PATH = "data/raw"
os.makedirs(DATA_RAW_PATH, exist_ok=True)

# Define USFS Feature Server URLs
USFS_TRAILS_URL = "https://apps.fs.usda.gov/arcx/rest/services/EDW/EDW_TrailNFSPublish_01/MapServer/0"
# USFS_TRAILHEADS_URL = "https://apps.fs.usda.gov/arcx/rest/services/EDW/EDW_Trailheads_01/MapServer/0"

# Initialize ArcGIS GIS object (No Authentication Needed for Public Data)
gis = GIS()

# %%
def gdf_from_feature_layer(feature_layer, wkid):
        if feature_layer.features:
            geojson = feature_layer.to_geojson
            gdf = gpd.read_file(geojson)
            # if gdf.geometry is None or gdf.geometry.is_empty.all():
            #     fixed_geojson = self._correct_multipolygon_nesting_as_string(
            #         geojson)
            #     gdf = gpd.read_file(fixed_geojson)
            gdf = gdf.to_crs(epsg=wkid)
            return gdf
        else:
            return gpd.GeoDataFrame()

# %%
def get_feature_layer_from_server(layer_url, bbox):
    """Fetch features from an Esri Feature Server using a bounding box."""
    feature_layer = FeatureLayer(layer_url, gis)
    wkid = 4326  # Ensure projection is in WGS84
    
    try:
        # Convert bbox to Esri's dictionary format
        bbox_dict = {
            "xmin": bbox[0], "ymin": bbox[1], "xmax": bbox[2], "ymax": bbox[3],
            "spatialReference": {"wkid": wkid}
        }
        
        print(bbox_dict)
        # Query Feature Layer
        query_filter = intersects(bbox_dict, sr=wkid)
        features = feature_layer.query(geometry_filter=query_filter, out_sr=wkid, out_fields="*")
        
        # Convert to GeoDataFrame
        gdf = gdf_from_feature_layer(features, wkid)
        if gdf.empty:
            print(f"No features found for {layer_url}")
            return None

        # Ensure CRS is in WGS84
        if gdf.crs is None or gdf.crs != "EPSG:4326":
            gdf = gdf.to_crs(epsg=4326)

        return gdf

    except Exception as e:
        print(f"Error fetching layer {layer_url}: {e}")
        return None

# %%
def fetch_usfs_data(bbox):
    """Fetch USFS trails and trailheads within the user's bounding box."""
    print("Fetching USFS Trails...")
    trails_gdf = get_feature_layer_from_server(USFS_TRAILS_URL, bbox)

    # print("Fetching USFS Trailheads...")
    # trailheads_gdf = get_feature_layer_from_server(USFS_TRAILHEADS_URL, bbox)

    # Save raw results for further processing
    if trails_gdf is not None:
        trails_gdf.to_file(f"{DATA_RAW_PATH}/usfs_trails.geojson", driver="GeoJSON")
    # if trailheads_gdf is not None:
    #     trailheads_gdf.to_file(f"{DATA_RAW_PATH}/usfs_trailheads.geojson", driver="GeoJSON")

    return trails_gdf

# %%
bbox = [-105.14490332783127, 37.03295622962676, -104.56681540041795, 37.489198771684514]

# %%
gdf = fetch_usfs_data(bbox)
# Out:
# Fetching USFS Trails...
# {'xmin': -105.14490332783127, 'ymin': 37.03295622962676, 'xmax': -104.56681540041795, 'ymax': 37.489198771684514, 'spatialReference': {'wkid': 4326}}

# %%
gdf.head()
# Out:
#   TRAIL_NO   TRAIL_NAME TRAIL_TYPE    TRAIL_CN     BMP     EMP  \
# 0     1309   NORTH FORK      TERRA  6818010465  1.3600  1.9300
# 1     1309   NORTH FORK      TERRA  6818010465  0.0000  0.2375
# 2   1300.A     SHORTCUT      TERRA  9497010465  0.0000  1.2900
# 3     1309   NORTH FORK      TERRA  6818010465  3.6880  3.6900
# 4     1301  BAKER CREEK      TERRA  7157010465  1.7944  2.7300
#
#    SEGMENT_LENGTH ADMIN_ORG MANAGING_ORG SECURITY_ID ATTRIBUTESUBSET  \
# 0          0.5700    021203       021203        0212   TrailNFS_MGMT
# 1          0.2375    021203       021203        0212   TrailNFS_MGMT
# 2          1.2900    021203       021203        0212   TrailNFS_MGMT
# 3          0.0020    021203       021203        0212   TrailNFS_MGMT
# 4          0.9356    021203       021203        0212   TrailNFS_MGMT
#
#    NATIONAL_TRAIL_DESIGNATION TRAIL_CLASS TERRA_BASE_SYMBOLOGY  \
# 0                           1           3                  TC3
# 1                           1           3                  TC3
# 2                           1           3                  TC3
# 3                           1           3                  TC3
# 4                           1           3                  TC3
#
#   ACCESSIBILITY_STATUS    TRAIL_SURFACE SURFACE_FIRMNESS TYPICAL_TRAIL_GRADE  \
# 0                 None  NATIVE MATERIAL             None              12-20%
# 1                 None  NATIVE MATERIAL             None              12-20%
# 2                 None  NATIVE MATERIAL             None              12-20%
# 3                 None  NATIVE MATERIAL             None              12-20%
# 4                 None  NATIVE MATERIAL             None              12-20%
#
#    TYPICAL_TREAD_WIDTH MINIMUM_TRAIL_WIDTH TYPICAL_TREAD_CROSS_SLOPE  \
# 0  TW03 - 18-24 INCHES                None                      None
# 1  TW03 - 18-24 INCHES                None                      None
# 2  TW03 - 18-24 INCHES                None                      None
# 3  TW03 - 18-24 INCHES                None                      None
# 4  TW03 - 18-24 INCHES                None                      None
#
#   SPECIAL_MGMT_AREA  MVUM_SYMBOL ALLOWED_TERRA_USE ALLOWED_SNOW_USE  \
# 0              None          NaN               321             None
# 1              None          NaN               321             None
# 2              None          7.0             54321             None
# 3              None          NaN               321             None
# 4              None          9.0              4321             None
#
#   HIKER_PEDESTRIAN_MANAGED HIKER_PEDESTRIAN_ACCPT_DISC  \
# 0                     None                 01/01-12/31
# 1                     None                 01/01-12/31
# 2                     None                 01/01-12/31
# 3                     None                 01/01-12/31
# 4                     None                 01/01-12/31
#
#   HIKER_PEDESTRIAN_RESTRICTED PACK_SADDLE_MANAGED PACK_SADDLE_ACCPT_DISC  \
# 0                        None         01/01-12/31                   None
# 1                        None         01/01-12/31                   None
# 2                        None                None                   None
# 3                        None         01/01-12/31                   None
# 4                        None                None                   None
#
#   PACK_SADDLE_RESTRICTED BICYCLE_MANAGED BICYCLE_ACCPT_DISC  \
# 0                   None            None        01/01-12/31
# 1                   None            None        01/01-12/31
# 2                   None            None        01/01-12/31
# 3                   None            None        01/01-12/31
# 4                   None            None        01/01-12/31
#
#   BICYCLE_RESTRICTED MOTORCYCLE_MANAGED MOTORCYCLE_ACCPT_DISC  \
# 0               None               None                  None
# 1               None               None                  None
# 2               None               None          01/01-12/31
# 3               None               None                  None
# 4               None        01/01-12/31                  None
#
#   MOTORCYCLE_RESTRICTED  ATV_MANAGED ATV_ACCPT_DISC ATV_RESTRICTED  \
# 0           01/01-12/31         None           None    01/01-12/31
# 1           01/01-12/31         None           None    01/01-12/31
# 2                  None  01/01-12/31           None           None
# 3           01/01-12/31         None           None    01/01-12/31
# 4                  None         None           None    01/01-12/31
#
#   FOURWD_MANAGED FOURWD_ACCPT_DISC FOURWD_RESTRICTED SNOWMOBILE_MANAGED  \
# 0           None              None       01/01-12/31               None
# 1           None              None       01/01-12/31               None
# 2           None              None       01/01-12/31               None
# 3           None              None       01/01-12/31               None
# 4           None              None       01/01-12/31               None
#
#   SNOWMOBILE_ACCPT_DISC SNOWMOBILE_RESTRICTED SNOWSHOE_MANAGED  \
# 0                  None                  None             None
# 1                  None                  None             None
# 2                  None                  None             None
# 3                  None                  None             None
# 4                  None                  None             None
#
#   SNOWSHOE_ACCPT_DISC SNOWSHOE_RESTRICTED XCOUNTRY_SKI_MANAGED  \
# 0                None                None                 None
# 1                None                None                 None
# 2                None                None                 None
# 3                None                None                 None
# 4                None                None                 None
#
#   XCOUNTRY_SKI_ACCPT_DISC XCOUNTRY_SKI_RESTRICTED MOTOR_WATERCRAFT_MANAGED  \
# 0                    None                    None                     None
# 1                    None                    None                     None
# 2                    None                    None                     None
# 3                    None                    None                     None
# 4                    None                    None                     None
#
#   MOTOR_WATERCRAFT_ACCPT_DISC MOTOR_WATERCRAFT_RESTRICTED  \
# 0                        None                        None
# 1                        None                        None
# 2                        None                        None
# 3                        None                        None
# 4                        None                        None
#
#   NONMOTOR_WATERCRAFT_MANAGED NONMOTOR_WATERCRAFT_ACCPT_DISC  \
# 0                        None                           None
# 1                        None                           None
# 2                        None                           None
# 3                        None                           None
# 4                        None                           None
#
#   NONMOTOR_WATERCRAFT_RESTRICTED  GIS_MILES TERRA_MOTORIZED SNOW_MOTORIZED  \
# 0                           None      0.592               N           None
# 1                           None      0.246               N           None
# 2                           None      1.313               Y           None
# 3                           None      0.002               N           None
# 4                           None      0.909               Y           None
#
#   WATER_MOTORIZED  OBJECTID  SHAPE.LEN HIKER_PEDESTRIAN_ACCPT  \
# 0            None    101462   0.008688                   None
# 1            None    102097   0.003630                   None
# 2            None    102602   0.020547                   None
# 3            None    102141   0.000029                   None
# 4            None    102047   0.016254                   None
#
#   HIKER_PEDESTRIAN_DISC PACK_SADDLE_ACCPT PACK_SADDLE_DISC BICYCLE_ACCPT  \
# 0                  None              None             None          None
# 1                  None              None             None          None
# 2                  None              None             None          None
# 3                  None              None             None          None
# 4                  None              None             None          None
#
#   BICYCLE_DISC MOTORCYCLE_ACCPT MOTORCYCLE_DISC ATV_ACCPT ATV_DISC  \
# 0         None             None            None      None     None
# 1         None             None            None      None     None
# 2         None      01/01-12/31            None      None     None
# 3         None             None            None      None     None
# 4         None             None            None      None     None
#
#   FOURWD_ACCPT FOURWD_DISC SNOWCOACH_SNOWCAT_MANAGED SNOWCOACH_SNOWCAT_ACCPT  \
# 0         None        None                      None                    None
# 1         None        None                      None                    None
# 2         None        None                      None                    None
# 3         None        None                      None                    None
# 4         None        None                      None                    None
#
#   SNOWCOACH_SNOWCAT_DISC SNOWCOACH_SNOWCAT_ACCPT_DISC  \
# 0                   None                         None
# 1                   None                         None
# 2                   None                         None
# 3                   None                         None
# 4                   None                         None
#
#   SNOWCOACH_SNOWCAT_RESTRICTED SNOWMOBILE_ACCPT SNOWMOBILE_DISC  \
# 0                         None             None            None
# 1                         None             None            None
# 2                         None             None            None
# 3                         None             None            None
# 4                         None             None            None
#
#   SNOWSHOE_ACCPT SNOWSHOE_DISC XCOUNTRY_SKI_ACCPT XCOUNTRY_SKI_DISC  \
# 0           None          None               None              None
# 1           None          None               None              None
# 2           None          None               None              None
# 3           None          None               None              None
# 4           None          None               None              None
#
#   MOTOR_WATERCRAFT_ACCPT MOTOR_WATERCRAFT_DISC NONMOTOR_WATERCRAFT_ACCPT  \
# 0                   None                  None                      None
# 1                   None                  None                      None
# 2                   None                  None                      None
# 3                   None                  None                      None
# 4                   None                  None                      None
#
#   NONMOTOR_WATERCRAFT_DISC E_BIKE_CLASS1_MANAGED E_BIKE_CLASS1_ACCPT  \
# 0                     None                  None                None
# 1                     None                  None                None
# 2                     None                  None         01/01-12/31
# 3                     None                  None                None
# 4                     None                  None         01/01-12/31
#
#   E_BIKE_CLASS1_DISC E_BIKE_CLASS1_RESTRICTED E_BIKE_CLASS2_MANAGED  \
# 0               None                     None                  None
# 1               None                     None                  None
# 2               None                     None                  None
# 3               None                     None                  None
# 4               None                     None                  None
#
#   E_BIKE_CLASS2_ACCPT E_BIKE_CLASS2_DISC E_BIKE_CLASS2_RESTRICTED  \
# 0                None               None                     None
# 1                None               None                     None
# 2         01/01-12/31               None                     None
# 3                None               None                     None
# 4         01/01-12/31               None                     None
#
#   E_BIKE_CLASS3_MANAGED E_BIKE_CLASS3_ACCPT E_BIKE_CLASS3_DISC  \
# 0                  None                None               None
# 1                  None                None               None
# 2                  None         01/01-12/31               None
# 3                  None                None               None
# 4                  None         01/01-12/31               None
#
#   E_BIKE_CLASS3_RESTRICTED                                GLOBALID  \
# 0                     None  {1EC41432-3CB0-4CE9-B591-F8E0D0FFBCAD}
# 1                     None  {513BD06E-60E6-440B-B559-E039C7ECA920}
# 2                     None  {FE7F799A-C3D9-4F33-9F00-F729A06AD5A2}
# 3                     None  {8621C5B2-83E9-4BDB-9BB9-81052B3F9299}
# 4                     None  {5A6ED52F-4718-4835-A781-251561A070F6}
#
#                                             geometry
# 0  MULTILINESTRING ((-105.1205 37.27029, -105.120...
# 1  MULTILINESTRING ((-105.10957 37.25502, -105.10...
# 2  MULTILINESTRING ((-105.14615 37.36034, -105.14...
# 3  MULTILINESTRING ((-105.13663 37.29866, -105.13...
# 4  MULTILINESTRING ((-105.12901 37.34943, -105.12...

# %%
gdf.columns
# Out:
# Index(['TRAIL_NO', 'TRAIL_NAME', 'TRAIL_TYPE', 'TRAIL_CN', 'BMP', 'EMP',
#        'SEGMENT_LENGTH', 'ADMIN_ORG', 'MANAGING_ORG', 'SECURITY_ID',
#        ...
#        'E_BIKE_CLASS2_MANAGED', 'E_BIKE_CLASS2_ACCPT', 'E_BIKE_CLASS2_DISC',
#        'E_BIKE_CLASS2_RESTRICTED', 'E_BIKE_CLASS3_MANAGED',
#        'E_BIKE_CLASS3_ACCPT', 'E_BIKE_CLASS3_DISC', 'E_BIKE_CLASS3_RESTRICTED',
#        'GLOBALID', 'geometry'],
#       dtype='object', length=105)

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c69197c9e02a855e1f70087e518a408 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c69197c9e02a855e1f70087e518a408&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c69197c9e02a855e1f70087e518a408 = L.map(
#                 &quot;map_0c69197c9e02a855e1f70087e518a408&quot;,
#                 {
#                     center: [37.35635786326604, -105.04515544833589],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0c69197c9e02a855e1f70087e518a408);
#
#
#
#
#
#             var tile_layer_85d1cb3f41de517302143b6e9da0753b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85d1cb3f41de517302143b6e9da0753b.addTo(map_0c69197c9e02a855e1f70087e518a408);
#
#
#             map_0c69197c9e02a855e1f70087e518a408.fitBounds(
#                 [[37.255015042483315, -105.1540603771166], [37.45770068404876, -104.93625051955517]],
#                 {}
#             );
#
#
#         function geo_json_d933a8d1469962daffc54c144a8b6f4d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d933a8d1469962daffc54c144a8b6f4d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d933a8d1469962daffc54c144a8b6f4d_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_d933a8d1469962daffc54c144a8b6f4d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d933a8d1469962daffc54c144a8b6f4d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_d933a8d1469962daffc54c144a8b6f4d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d933a8d1469962daffc54c144a8b6f4d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d933a8d1469962daffc54c144a8b6f4d = L.geoJson(null, {
#                 onEachFeature: geo_json_d933a8d1469962daffc54c144a8b6f4d_onEachFeature,
#
#                 style: geo_json_d933a8d1469962daffc54c144a8b6f4d_styler,
#                 pointToLayer: geo_json_d933a8d1469962daffc54c144a8b6f4d_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_d933a8d1469962daffc54c144a8b6f4d_add (data) {
#             geo_json_d933a8d1469962daffc54c144a8b6f4d
#                 .addData(data);
#         }
#             geo_json_d933a8d1469962daffc54c144a8b6f4d_add({&quot;bbox&quot;: [-105.1540603771166, 37.255015042483315, -104.93625051955517, 37.45770068404876], &quot;features&quot;: [{&quot;bbox&quot;: [-105.12251286916313, 37.27028938605244, -105.120502276994, 37.277651907009364], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-105.120502276994, 37.27028938605244], [-105.12062171903023, 37.270382844058766], [-105.12070972906776, 37.27056397707996], [-105.12112693218516, 37.270797352088465], [-105.12132395423377, 37.270836556082074], [-105.12143484728367, 37.27109186911269], [-105.12175470038079, 37.27134408013001], [-105.12190926343418, 37.27153309214818], [-105.12195720848463, 37.27194221320533], [-105.12185645747742, 37.272104486235385], [-105.1
